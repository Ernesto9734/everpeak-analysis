# %% [markdown]
# # ¡Hola Ernesto!
#
# Mi nombre es Sofia Arboleda, estaré ayudándote a revisar este proyecto para que quede en su mejor versión.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. Esto es útil para que te acostumbres a un escenario laboral. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Encontrarás mis comentarios más abajo - **por favor, no los muevas, no los modifiques ni los borres**.
#
# ¿Cómo funciona esta revisión? Leeré atentamente tu código y te señalaré tus fortalezas y aquellas cosas que podemos mejorar. Los comentarios aparecerán de esta forma:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora</b> <a class="tocSkip"></a>
#
# Si todo está perfecto y no se requieren cambios en el código.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario de la revisora</b> <a class="tocSkip"></a>
#
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta. Se aceptan uno o dos comentarios de este tipo en el borrador, pero si hay más, deberás hacer las correcciones.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario de la revisora</b> <a class="tocSkip"></a>
#
# Si definitivamente hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma si algo no queda claro (copia este código en una celda markdown):
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Hola, muchas gracias por tus comentarios y la revisión.
# </div>
#
# **Es un gusto acompañarte en este proceso, ¡empecemos!**

# %% [markdown]
# ## Introducción
#
# Como analista de datos, tu objetivo es **evaluar cómo la movilidad urbana se relaciona con la productividad económica en las principales ciudades latinoamericanas**.
# Para ello trabajarás con datos reales de TomTom Traffic Index y OECD Cities, que deberás limpiar, combinar y analizar para identificar en qué ciudades conviene invertir en infraestructura de transporte.

# %% [markdown]
# ### Comentario General Iteración #1
# <div class="alert alert-block alert-success">
#
# Ernesto, quería dejarte aquí una apreciación general de tu proyecto para que a partir de allí nos vayamos punto por punto.
#
# Respecto a tu trabajo en esta primera iteración, has mostrado tus conocimientos de la mejor forma, utilizando los metodos correctamente, realizando filtros de forma sencilla y trabajando con las librerias par graficar de la mejor forma. Solo quedan algunas recomendaciones de mejora que te servirán para tus entregas a futuro y corregir el desarrollo.
#
# Sigue aprendiendo bastante en este camino, saludos!
# </div>

# %% [markdown]
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de ambos datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯Objetivo:**
# Importar las librerías necesarias, cargar los archivos CSV en DataFrames y realizar una revisión preliminar para entender su contenido.
#
# **Instrucciones:**
# - Importa las librerías `pandas`, `numpy`, `seaborn` y `matplotlib.pyplot`.
# - Carga los archivos usando `pd.read_csv()`:
#   - `'/datasets/tomtom_traffic.csv'`
#   - `/datasets/oecd_city_economy.csv` `.
# - Guarda los DataFrames en las variables `traffic` y `eco`.
# - Muestra las primeras 5 filas de cada DataFrame.

# %%
# importar librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargar archivos
traffic = pd.read_csv('/datasets/tomtom_traffic.csv')
eco = pd.read_csv('/datasets/oecd_city_economy.csv')#completa el código

# %%
# mostrar las primeras 5 filas de traffic
traffic.head(5)
# Out:
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
# 3     ARE  abu-dhabi  2025-01-13 01:46:30.001        8.2               2.0
# 4     ARE  abu-dhabi  2025-01-13 00:01:30.000        1.1               1.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
# 3              4.1        2.0                  2.0  2025-01-06 01:46:30.000
# 4              0.2        1.0                  1.0  2025-01-06 00:01:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232
# 3                    7.723808                        7.899046  -0.175238
# 4                    8.336363                        8.604379  -0.268016

# %%
# mostrar las primeras 5 filas de eco
eco.head(5)
# Out:
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
# 3  2023        brasilia     Brazil       15.999,00           8.3%
# 4  2023        salvador     Brazil        8.761,00          13.1%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60
# 3         13,50           4,70
# 4         16,00           3,90

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Buen trabajo con la importación de las librerías y datasets requeridos, al igual que con los métodos para la exploración inicial de los datos.

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Explorar, limpiar y preparar los datos
#
# Antes de combinar los datasets, inspecciona su estructura, tipos de datos, columnas y valores faltantes.
# Anota las columnas que necesiten limpieza y luego estandariza los nombres de columnas.
#
# ### 2.1 Explorar la estructura y tipos de datos
#
# **🎯Objetivo:**
# Identificar columnas con tipos incorrectos, distribución y nulos, anotar las columnas que requieren conversión.
#
# **Instrucciones:**
#
# - Usa `.info()` para conocer la estructura de ambos DataFrames.
# - Muestra los primeros 3 renglones de cada DF.
# - Identifica si los detalles de cada DF estan bien o si requieren correcciones y escribe tus conclusiones en el bloque Markdown.
#   - ¿Hay columnas que requieren conversión?¿ Cuáles son? ¿Que tipo de dato ienen y cuál deberían de tener?
#   - ¿Hay datos ausentes en alguna columna?

# %%
# Examinar la estructura de traffic
traffic.info()
print('Datos nulos:', traffic.isna().sum().sum())
traffic.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Country                         1004464 non-null  object
#  1   City                            1004464 non-null  object
#  2   UpdateTimeUTC                   1004464 non-null  object
#  3   JamsDelay                       1004464 non-null  float64
#  4   TrafficIndexLive                1004464 non-null  float64
#  5   JamsLengthInKms                 1004464 non-null  float64
#  6   JamsCount                       1004464 non-null  float64
#  7   TrafficIndexWeekAgo             1004464 non-null  float64
#  8   UpdateTimeUTCWeekAgo            1004464 non-null  object
#  9   TravelTimeLivePer10KmsMins      1004464 non-null  float64
#  10  TravelTimeHistoricPer10KmsMins  1004464 non-null  float64
#  11  MinsDelay                       1004464 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 92.0+ MB
# Datos nulos: 0
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232

# %% [markdown]
# En la estructura del DF traffic, se observa que:
#
# 1. Tipificación de Variables Categóricas: Se procederá con la conversión de las columnas 'country' y 'city' de tipo object a string. Este ajuste asegura la integridad de los metadatos y da cumplimiento estricto al diccionario de especificaciones del proyecto.
#
# 2. Normalización Cronológica: Se ha identificado que las columnas 'UpdateTimeUTC' y 'UpdateTimeUTCWeekAgo' presentan un formato object. Para habilitar el análisis de series de tiempo y garantizar la precisión en la cronología de los eventos, se tipificarán al formato estándar datetime.
#
# 3. Validación de Integridad: Tras ejecutar la función .isna(), se confirma la ausencia de valores nulos explícitos en el conjunto de datos, asegurando una base sólida para el procesamiento estadístico subsiguiente.

# %%
# Examinar la estructura de eco
eco.info()
print('Datos nulos:', eco.isna().sum().sum())
eco.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             30 non-null     int64
#  1   City             30 non-null     object
#  2   Country          30 non-null     object
#  3   City GDP/capita  30 non-null     object
#  4   Unemployment %   30 non-null     object
#  5   PM2.5 (μg/m³)    30 non-null     object
#  6   Population (M)   30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB
# Datos nulos: 0
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60

# %% [markdown]
# En la estructura del DF eco, se observa que:
#
# 1. Normalización de Variables Categóricas: Se procederá con la tipificación de las columnas 'country' y 'city', actualmente almacenadas como tipo object. Con el objetivo de asegurar la integridad de los datos y dar cumplimiento al diccionario de especificaciones, ambas variables serán convertidas explícitamente al tipo string.
#
# 2. Corrección de Variables Numéricas de Alto Impacto: Las columnas 'City GDP/capital', 'Unemployment %', 'PM2.5 (ug/m3)' y 'Population (M)' presentan una tipificación inadecuada como object. Dado que estas variables son críticas para el análisis estadístico y el modelado posterior, se realizará su conversión forzada al tipo float. Este ajuste es indispensable para habilitar el cálculo de métricas y correlaciones.
#
# 3. Verificación de Integridad y Valores Faltantes: Se ha confirmado, mediante la ejecución de la función .isna(), que el conjunto de datos no presenta valores nulos explícitos. Esto garantiza una base de datos completa para el inicio de la fase de procesamiento.

# %% [markdown]
# ### 2.2 Renombrar columnas
#
# **🎯Objetivo:**
# Estandarizar los nombres de columnas para evitar errores y facilitar la unión de los datasets.
#
# **Instrucciones:**
#
# - Cambia los nombres de las columnas para que tengan el formato `snake_case`.
#     - `Country` → `country`
#     - `UpdateTimeUTC` → `update_time_utc`
# - Verifica que los cambios se hayan aplicado correctamente usando `.columns`.

# %%
# Estandarizar los nombres de las columnas de traffic
#tu código aquí
traffic_clean = traffic.rename(
    columns = {
        'Country' : 'country',
        'City' : 'city',
        'UpdateTimeUTC' : 'update_time_utc',
        'JamsDelay' : 'jams_delay',
        'TrafficIndexLive' : 'traffic_index_live',
        'JamsLengthInKms' : 'jams_length_in_kms',
        'JamsCount' : 'jams_count',
        'TrafficIndexWeekAgo' : 'traffic_index_week_ago',
        'UpdateTimeUTCWeekAgo' : 'update_time_utc_week_ago',
        'TravelTimeLivePer10KmsMins' : 'travel_time_live_per_10_kms_mins',
        'TravelTimeHistoricPer10KmsMins' : 'travel_time_historic_per_10_kms_mins',
        'MinsDelay' : 'mins_delay'
    }
)
traffic_clean.columns
# Out:
# Index(['country', 'city', 'update_time_utc', 'jams_delay',
#        'traffic_index_live', 'jams_length_in_kms', 'jams_count',
#        'traffic_index_week_ago', 'update_time_utc_week_ago',
#        'travel_time_live_per_10_kms_mins',
#        'travel_time_historic_per_10_kms_mins', 'mins_delay'],
#       dtype='object')

# %%
# Estandarizar los nombres de las columnas de eco
#tu código aquí
eco_clean = eco.rename(
    columns = {
        'Year' : 'year',
        'City' : 'city',
        'Country' : 'country',
        'City GDP/capita' : 'city_gdp_capita',
        'Unemployment %' : 'unemployment_pct',
        'PM2.5 (μg/m³)' : 'pm_2.5_μg/m3',
        'Population (M)' : 'population_m'
    }
)
# verificar cambios
eco_clean.columns
# Out:
# Index(['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct',
#        'pm_2.5_μg/m3', 'population_m'],
#       dtype='object')

# %% [markdown]
# ### 2.3 Corregir formatos numéricos y de fecha
#
# **🎯Objetivo:**
# Asegurar que las columnas de fechas y valores numéricos estén en formatos correctos para permitir análisis, cálculos y comparaciones precisas.
#
# **Instrucciones:**
#
# - Convierte las columnas de fecha de `traffic` a formato `datetime`. Haz el cambio a prueba de errores.
# - En el dataset `eco`, limpia los valores numéricos:
#     - En `city_gdp_capita`: elimina separadores de miles (`.`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `unemployment_pct`: elimina el símbolo de porcentaje (`%`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `population_m`: reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
# - Finalmente, crea una nueva columna llamada `population` multiplicando `population_m` por 1,000,000 para obtener la población total.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# para eliminar símbolos, puedes reemplazarlos por un texto vacío.

# %%
# Convertir las columnas de traffic a tipo fecha con pd.to_datetime()
traffic_clean['update_time_utc'] = pd.to_datetime(traffic_clean['update_time_utc'], errors='coerce')#tu código aquí
traffic_clean['update_time_utc_week_ago'] = pd.to_datetime(traffic_clean['update_time_utc_week_ago'], errors='coerce')#tu código aquí

# verificar el cambio
traffic_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count    Dtype
# ---  ------                                --------------    -----
#  0   country                               1004464 non-null  object
#  1   city                                  1004464 non-null  object
#  2   update_time_utc                       1004464 non-null  datetime64[ns]
#  3   jams_delay                            1004464 non-null  float64
#  4   traffic_index_live                    1004464 non-null  float64
#  5   jams_length_in_kms                    1004464 non-null  float64
#  6   jams_count                            1004464 non-null  float64
#  7   traffic_index_week_ago                1004464 non-null  float64
#  8   update_time_utc_week_ago              1004464 non-null  datetime64[ns]
#  9   travel_time_live_per_10_kms_mins      1004464 non-null  float64
#  10  travel_time_historic_per_10_kms_mins  1004464 non-null  float64
#  11  mins_delay                            1004464 non-null  float64
# dtypes: datetime64[ns](2), float64(8), object(2)
# memory usage: 92.0+ MB

# %%
# Limpia separadores y convierte columnas numéricas en eco
eco_clean['city_gdp_capita'] = (
    eco_clean['city_gdp_capita']
        .astype(str)
        .str.replace('.', '')
        .str.replace(',', '.')
        .astype(float)
)

eco_clean['unemployment_pct'] = (
    eco_clean['unemployment_pct']
    .astype(str)
    .str.replace('%', '')
    .astype(float)
)

eco_clean['population_m'] = (
    eco_clean['population_m']
    .astype(str)
    .str.replace(',', '.')
    .astype(float)
)

eco_clean['pm_2.5_μg/m3'] = (
    eco_clean['pm_2.5_μg/m3']
    .astype(str)
    .str.replace(',', '.')
    .astype(float)
)

# Calcula la población total en unidades absolutas (Multiplica * 1000000)
# eco['population'] = ...
eco_clean['population'] = (
    eco_clean['population_m'] * 1000000
)

# verificar el cambio
eco_clean.info()
eco_clean.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              30 non-null     int64
#  1   city              30 non-null     object
#  2   country           30 non-null     object
#  3   city_gdp_capita   30 non-null     float64
#  4   unemployment_pct  30 non-null     float64
#  5   pm_2.5_μg/m3      30 non-null     float64
#  6   population_m      30 non-null     float64
#  7   population        30 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 2.0+ KB
#    year            city    country  city_gdp_capita  unemployment_pct  \
# 0  2023    buenos-aires  Argentina          15782.0               6.2
# 1  2023       sao-paulo     Brazil          14475.0               9.1
# 2  2023  rio-de-janeiro     Brazil          13142.0               9.8
#
#    pm_2.5_μg/m3  population_m  population
# 0          15.2          15.3  15300000.0
# 1          29.5          22.5  22500000.0
# 2          19.1          13.6  13600000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Bien hecho! Has comprendido la estructura y tipo de datos, has corregido la nomenclatura de las columnas en el formato snake_case y los formatos de números y fechas. Buen trabajo.

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Extraer año y filtrar
#
# Extraer el año permite filtrar la información y trabajar solo con el período más reciente y relevante.
#
# ### 3.1 Extraer columna año y filtrar 2024
#
# **🎯Objetivo**
# Identificar el año de cada registro y mantener solo los registros del 2024.
#
# **Intrucciones**
#
# - Como el DataFrame `traffic` no tiene una columna de año, utiliza el atributo `.dt.year` sobre su columna de fecha para crear una nueva columna llamada `year`.
# - Filtra las filas donde el año sea **2024**.
# - Utiliza `.copy()` para crear dos nuevos DataFrames (`traffic_2024` y `eco_2024`) para evitar modificar el dataset original.

# %%
# Extraer el año de las fechas en update_time_utc
traffic_clean['year'] = traffic_clean['update_time_utc'].dt.year

# Verificar cambio
traffic_clean.head(3)
# Out:
#   country       city         update_time_utc  jams_delay  traffic_index_live  \
# 0     ARE  abu-dhabi 2025-01-13 04:01:30.001       650.7                36.0
# 1     ARE  abu-dhabi 2025-01-13 03:46:00.000       540.4                30.0
# 2     ARE  abu-dhabi 2025-01-13 02:46:30.000        71.8                 7.0
#
#    jams_length_in_kms  jams_count  traffic_index_week_ago  \
# 0               109.1       162.0                    30.0
# 1               101.4       136.0                    27.0
# 2                18.9        23.0                     6.0
#
#   update_time_utc_week_ago  travel_time_live_per_10_kms_mins  \
# 0  2025-01-06 04:01:30.000                         11.614767
# 1  2025-01-06 03:46:30.001                         11.003180
# 2  2025-01-06 02:46:30.000                          8.196278
#
#    travel_time_historic_per_10_kms_mins  mins_delay  year
# 0                             10.265330    1.349437  2025
# 1                             10.031544    0.971635  2025
# 2                              8.196510   -0.000232  2025

# %%
# Filtra los registros del año 2024
traffic_2024 = traffic_clean[traffic_clean['year']==2024].reset_index(drop=True).copy()
eco_2024 = eco_clean[eco_clean['year']==2024].reset_index(drop=True).copy()

# Revisar dataframes nuevos
display(traffic_2024.head())
display(eco_2024.head())
# Out:
#   country       city         update_time_utc  jams_delay  traffic_index_live  \
# 0     ARE  abu-dhabi 2024-12-31 23:01:30.000        12.9                 5.0
# 1     ARE  abu-dhabi 2024-12-31 22:01:30.000       136.0                21.0
# 2     ARE  abu-dhabi 2024-12-31 21:16:30.000       455.2                31.0
# 3     ARE  abu-dhabi 2024-12-31 20:01:00.001       399.4                27.0
# 4     ARE  abu-dhabi 2024-12-31 19:46:00.000       366.4                28.0
#
#    jams_length_in_kms  jams_count  traffic_index_week_ago  \
# 0                 2.5         5.0                     2.0
# 1                20.6        32.0                     3.0
# 2                40.4        72.0                     4.0
# 3                38.0        75.0                     6.0
# 4                39.8        82.0                     9.0
#
#   update_time_utc_week_ago  travel_time_live_per_10_kms_mins  \
# 0  2024-12-24 23:01:30.001                          8.560399
# 1  2024-12-24 22:01:30.000                         10.355732
# 2  2024-12-24 21:01:30.000                         11.456878
# 3  2024-12-24 20:01:30.001                         11.670062
# 4  2024-12-24 19:01:00.000                         11.686322
#
#    travel_time_historic_per_10_kms_mins  mins_delay  year
# 0                              8.519634    0.040765  2024
# 1                              9.049445    1.306286  2024
# 2                              9.305174    2.151704  2024
# 3                              9.952811    1.717252  2024
# 4                             10.008469    1.677853  2024
#    year            city    country  city_gdp_capita  unemployment_pct  \
# 0  2024    buenos-aires  Argentina          18117.0               7.2
# 1  2024       sao-paulo     Brazil          14703.0               8.5
# 2  2024  rio-de-janeiro     Brazil          13349.0               9.2
# 3  2024        brasilia     Brazil          16251.0               7.8
# 4  2024        salvador     Brazil           8899.0              12.4
#
#    pm_2.5_μg/m3  population_m  population
# 0          14.5          15.4  15400000.0
# 1          28.0          22.6  22600000.0
# 2          18.4          13.7  13700000.0
# 3          12.8           4.8   4800000.0
# 4          15.2           3.9   3900000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo en este caso, pudiste filtrar de forma adecuada los datos para el año 2024 haciendo uso de los métodos necesarios para ello.

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Analizar y resumir datos de movilidad
#
# Como el dataset de tráfico contiene **múltiples registros por ciudad**. En esta parte, calcularás los promedios anuales por ciudad para simplificar el análisis y obtener una visión más clara de las tendencias generales.
#
# ### 4.1 Calcular promedios de tráfico por ciudad
#
# **🎯Objetivo:**
# Obtener una vista consolidada del tráfico promedio por ciudad y año, para analizar patrones generales sin depender de datos diarios.
#
# **Instrucciones**
#
# - Agrupa los datos por `city`, `country` y `year`.
# - Calcula el promedio **solo de las métricas de tráfico más relevantes**: como `jams_delay`, `traffic_index_live`, `jams_length_kms`, `jams_count`, `mins_delay`, y tiempos de viaje (`travel_time_live_per_10kms_mins` y `travel_time_hist_per_10kms_mins`).
# - Guarda el resultado como `traffic_city_year_2024`, mantén las columnas como variables (no índices).

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa ".agg()" para aplicar funciones de promedio. Al final, reinicia el índice para mantener las columnas de la agrupación como variables (no índices).

# %%
# Calcular los  promedios de trafico por ciudad, país y año

parametros = ['jams_delay', 'traffic_index_live', 'jams_length_in_kms', 'jams_count', 'mins_delay', 'travel_time_live_per_10_kms_mins', 'travel_time_historic_per_10_kms_mins']
traffic_city_year_2024 =  (traffic_2024.groupby(['city', 'country', 'year'], as_index=False)[parametros]
.mean())
# tu código aqui

# Mostrar resultado
traffic_city_year_2024.head()
# Out:
#         city country  year  jams_delay  traffic_index_live  \
# 0   a-coruna     ESP  2024   17.935187           15.259774
# 1     aachen     DEU  2024   26.732141           20.960314
# 2     aarhus     DNK  2024   21.200616           16.575891
# 3  abu-dhabi     ARE  2024  171.157315           13.902028
# 4      adana     TUR  2024   83.864761           22.541040
#
#    jams_length_in_kms  jams_count  mins_delay  \
# 0            2.198002    4.934405    0.774172
# 1            3.892586    6.601832    0.792968
# 2            2.736736    6.109987    0.495276
# 3           24.507380   47.268019    0.139764
# 4           11.827331   23.754620    1.129749
#
#    travel_time_live_per_10_kms_mins  travel_time_historic_per_10_kms_mins
# 0                         16.267977                             15.493804
# 1                         13.397861                             12.604894
# 2                         15.219292                             14.724016
# 3                          9.829092                              9.689328
# 4                         15.879694                             14.749945

# %% [markdown]
# ### 🧠 **Momento de reflexión**
#
# ¡Excelente trabajo hasta aquí!
#
# Ahora que ya tienes los promedios anuales por ciudad, es momento de **observarlos** con atención.
#
# Piensa:
#
# - ¿Cuál crees que tiene el mayor tiempo promedio de tráfico?
# - ¿Será una ciudad de **Europa**, de **Latinoamérica** o de **otra región** del mundo?
#
# Para descubrirlo, ejecuta esta línea de código:
#
# `traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)`
#
#
# 🔍 Observa qué ciudad aparece en los primeros lugares.
#
# ¿Te sorprenden los resultados? , ¿Coinciden con lo que imaginabas?

# %%
# tu código aquí
traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)
# Out:
#             city country  year   jams_delay  traffic_index_live  \
# 221  mexico-city     MEX  2024  2833.057892           34.218190
# 352        tokyo     JPN  2024  2152.574357           36.805059
# 246     new-york     USA  2024  2133.400000           28.210388
# 200       london     GBR  2024  2050.703662           29.230166
# 211       manila     PHL  2024  1741.493381           66.129402
# ..           ...     ...   ...          ...                 ...
# 111      dunedin     NZL  2024     4.651175           15.430809
# 363      uppsala     SWE  2024     4.194486           13.939168
# 123     fujairah     ARE  2024     4.025959           10.907719
# 12        almere     NLD  2024     3.633523            6.290478
# 117      el-paso     USA  2024     0.299024            2.340435
#
#      jams_length_in_kms  jams_count  mins_delay  \
# 221          389.239265  594.969392    1.855542
# 352          373.069734  518.809420    0.698152
# 246          398.227892  544.474902    1.396351
# 200          287.632868  471.795554    1.325160
# 211          246.858082  341.881205    2.469894
# ..                  ...         ...         ...
# 111            0.712315    1.591384    0.633294
# 363            0.656368    1.349672    0.501802
# 123            0.731910    1.373006    0.194951
# 12             0.506362    1.064063   -0.017544
# 117            0.031114    0.078118   -0.250676
#
#      travel_time_live_per_10_kms_mins  travel_time_historic_per_10_kms_mins
# 221                         21.809092                             19.953550
# 352                         22.443778                             21.745626
# 246                         18.505043                             17.108691
# 200                         17.714139                             16.388979
# 211                         27.134629                             24.664734
# ..                                ...                                   ...
# 111                         16.226009                             15.592715
# 363                         15.746717                             15.244916
# 123                         11.662590                             11.467639
# 12                           9.467150                              9.484694
# 117                         10.690269                             10.940945
#
# [387 rows x 10 columns]

# %% [markdown]
# La ciudad con el mayor tiempo promedio de tráfico es Ciudad de México en México.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo con `groupby` para agrupar por ciudad pais y año, al igual que la creacion de las columnas para las medias por indicador.
#
# La verificación que hiciste para descubrir a CDMX como la ciudad con mayor promedio de trafico está perfecta.

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Unir movilidad y economía
#
# Combinar datasets te permite analizar cómo se relacionan los indicadores económicos con los de movilidad.
#
# ### 5.1 Unir tráfico (tabla principal) con indicadores económicos
#
# **🎯Objetivo:**
# Combinar la información de tráfico y economía en un solo DataFrame para analizar cómo las condiciones económicas se relacionan con la movilidad urbana.
#
# **Instrucciones**
# - Selecciona solo las **columnas relevantes** de cada dataset (por ejemplo, variables clave de tráfico y de economía).
# - Usa `.copy()` al crear subconjuntos para evitar modificar el dataset original.
# - Une ambos DataFrames y define como **claves de unión** a `city` y `year`.
# - Mantén solo las ciudades y años presentes en ambos datasets.
# - Guarda el resultado en una nueva variable llamada `merged` y muestra las primeras 5 filas.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Aplica una unión de tipo "inner" para mantener las ciudades y años presentes en ambos datasets.

# %%
# Seleccionar columnas clave de tráfico y economía
left_cols = ['city','country','year','jams_delay','traffic_index_live',
             'jams_length_in_kms','jams_count','mins_delay',
             'travel_time_live_per_10_kms_mins','travel_time_historic_per_10_kms_mins']

right_cols = ['city','year','city_gdp_capita','unemployment_pct','pm_2.5_μg/m3','population']

# Usar .copy() para crear los dos nuevos datasets reducidos
traffic_2024_small = traffic_city_year_2024[left_cols].copy()
# traffic_2024_small = traffic_city_year_2024[ ... ].copy()
eco_2024_small = eco_clean[right_cols].copy()
# eco_2024_small = ...

# Unir datasets
merged = pd.merge(traffic_2024_small, eco_2024_small, on=['city', 'year'], how='inner')

# Mostrar las primeras 5 filas
merged.head()
# tu código aquí
# Out:
#              city country  year   jams_delay  traffic_index_live  \
# 0  belo-horizonte     BRA  2024   263.047879           19.428946
# 1          bogota     COL  2024  1141.552364           37.614273
# 2        brasilia     BRA  2024   101.576326           11.258220
# 3    buenos-aires     ARG  2024   571.089593           17.756012
# 4        curitiba     BRA  2024   183.469274           14.954545
#
#    jams_length_in_kms  jams_count  mins_delay  \
# 0           44.038129   68.805422    0.487228
# 1          140.893564  230.566550    1.699628
# 2           18.337133   27.280140    0.193442
# 3          100.287844  137.359860    0.416566
# 4           30.050044   46.898164    0.139965
#
#    travel_time_live_per_10_kms_mins  travel_time_historic_per_10_kms_mins  \
# 0                         18.304538                             17.817311
# 1                         24.992185                             23.292557
# 2                         13.338658                             13.145216
# 3                         17.907916                             17.491349
# 4                         17.258700                             17.118736
#
#    city_gdp_capita  unemployment_pct  pm_2.5_μg/m3  population
# 0          11124.0               9.5          16.8   6100000.0
# 1          11442.0              10.0          17.6  11300000.0
# 2          16251.0               7.8          12.8   4800000.0
# 3          18117.0               7.2          14.5  15400000.0
# 4          12381.0               8.2          13.5   3700000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Seleccionaste correctamente las columnas necesarias de ambos DataFrames y ejecutaste `pd.merge(..., on=['city','year'], how='inner')` como se solicitó. También realizaste un buen trabajo de verificación con `.head()`.

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Visualización y análisis de relaciones
#
# Ahora que tienes un dataset limpio y unificado, es momento de **visualizar patrones**.
# Los gráficos te ayudarán a entender cómo se relacionan las variables económicas con las de movilidad urbana.
#
# ### 6.1 Visualizar relaciones entre economía y tráfico
#
# **🎯Objetivo:**
# Analizar visualmente la distribución y la relación entre indicadores de tráfico y economía en 2024, para identificar posibles patrones o tendencias generales entre ambas variables.
#
# **Instrucciones**
# - Usa las librerías `seaborn` y `matplotlib.pyplot` para generar los gráficos.
# - Visualiza la distribución del **tráfico** (`jams_delay`) mediante:
#     - **Boxplot** → para observar la media, mediana y detectar valores atípicos.
# - Visualiza la distribución de la **economía** (`city_gdp_capita`) mediante:
#     - **Histograma** → para analizar la forma de la distribución y el valor promedio del PIB per cápita.
# - Finalmente, **compara ambas variables**, para observar si existe alguna relación entre ellas, haciendo un solo gráfico de barras donde aparezcan ambos indicadores.
# - Recuerda agregar título y etiquetas a los ejes de tus gráficos.
# - Observa y comenta los patrones, valores extremos o posibles relaciones que identifiques.

# %% [markdown]
# **Tip:** Dentro de los parentesis del boxplot, agrega `showmeans=True` para ver la media en el gráfico.

# %%
# Crear boxplot para observar el comportamiento de los minutos de congestion JamsDelay
# crea tu gráfico
sns.boxplot(merged['jams_delay'])
# obtener promedio para mostrarlo en título
mean_value = merged['jams_delay'].mean()
plt.title(f'Boxplot de JamsDelay (2024)\nPromedio: {mean_value:.2f}')
plt.show()

# %%
# Crear histograma para ver la distribución de la economía (city_gdp_capita)

# Suponiendo que tu DataFrame se llama 'df' y la columna 'gdp_per_capita'
plt.figure(figsize=(10, 6))
mean_val = merged['city_gdp_capita'].mean()

# Crear el histograma con curva de densidad (KDE)
sns.histplot(merged['city_gdp_capita'], kde=True, color='royalblue')

# Añadir línea del promedio
plt.axvline(mean_val, color='red', linestyle='--', label=f'Promedio: {mean_val:.2f}')

plt.title('Distribución del PIB per cápita')
plt.xlabel('PIB per cápita (USD)')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()

# %%
merged.plot(kind='bar', x='city', y=['jams_delay', 'city_gdp_capita'], figsize=(12, 6))
plt.title('Comparación: Retraso por Tráfico vs PIB per cápita')
plt.ylabel('Valor (Escala mixta)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Tip:** Antes del `plt.show()` agrega el código `plt.xticks(rotation=90)` para rotar las etiquetas del eje X en 90 grados.

# %% [markdown]
# ### 🧠 **Reflexiona**
# Excelente trabajo llegando a esta etapa del análisis. Antes de avanzar, revisa tus gráficos, tómate un momento para pensar:
#
# * ¿Las ciudades con mayor PIB per cápita también presentan más congestión? Los datos demuestran que el nivel de ingresos no es el único determinante de la saturación vial. En el caso de Montevideo, la relación espacio-habitante favorece un tráfico moderado a pesar de su elevado ingreso per cápita. Este fenómeno sugiere que la densidad urbana actúa como una variable moderadora crítica en la eficiencia de los sistemas de transporte.
#
# * ¿O sucede lo contrario, o no existe una relación clara? La relación entre riqueza y tráfico es difusa debido al uso de variables normalizadas. El PIB per cápita suaviza el efecto de la escala urbana, impidiendo visualizar la incidencia directa de la actividad económica en la movilidad. Un análisis basado en valores absolutos permitiría observar cómo la magnitud total de la economía de una ciudad —y no solo su riqueza promedio— tensiona la capacidad de sus sistemas de transporte.

# %% [markdown]
# Escribe tus comentarios:

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Graficaste correctamente con sns.boxplot() para el tráfico y con sns.histplot() correctamente para la economia con etiquetas adecuadas. También graficaste correctamente en barras las variables jams_delay vs city_gdp_capita, pero si lo notas, hay una diferencia grande en terminos de los rangos de cada columna, de forma que jamsdelay se ve achatado en cero. Para ello debes usar un eje extra que permita visualizar bien los datos.

# %% [markdown]
# ---
#
# ## 🧩Paso 7: Exportar y documentar resultados
#
# En esta etapa final consolidarás todo tu trabajo: guardarás el dataset limpio y crearás un resumen que documente los resultados del proyecto.
#
# ### 7.1 Guardar dataset final
#
# **🎯Objetivo:**
# Generar un CSV limpio, reproducible y con columnas relevantes para análisis posterior.
#
# **Instrucciones**
#
# - Exporta el DataFrame `merged` con el nombre: `ladb_mobility_economy_2024_clean.csv`
# - Usa `index=False` para no incluir el índice.

# %%
# Exporta el dataset final como CSV
merged.to_csv("ladb_mobility_economy_2024_clean.csv", index=False)

# %% [markdown]
# Para poder ver o descargar el archivo generado:
# En el menú lateral que esta a la izquierda, ve hasta la parte de abajo, a la sección de **Exportar dataset** para más información.

# %% [markdown]
# ---
#
# ## ✅ Entregables
#
# 1. **Notebook `.ipynb`** con todas las celdas (código + comentarios).
# 2. **CSV final**: `ladb_mobility_economy_2024_clean.csv`.
# 3. **Resumen ejecutivo breve** en Markdown (3–5 párrafos).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Bien hecho! Creaste el archivo final como CSV.

# %% [markdown]
# ---
#
# # 🧾 Resumen ejecutivo (plantilla)
#
# > Completa este resumen al finalizar el análisis. Mantén 3–5 párrafos cortos, claros y accionables.
#
# **Contexto & objetivo:**
# - Responde la pregunta central del análisis: ¿qué relación existe entre la movilidad urbana (congestión, tiempos de viaje) y la productividad económica (PIB per cápita)?
#   * La relación entre movilidad urbana y productividad económica no es lineal, ya que está condicionada por la densidad poblacional. El uso del PIB per cápita como métrica de desarrollo introduce un sesgo significativo: al normalizar la riqueza por habitante, se omite que es precisamente la concentración de esa población la que genera la presión física sobre la red vial. Por tanto, la correlación solo es comparable entre ciudades con estructuras demográficas similares.
#
# - Explica brevemente las variables clave utilizadas y su relevancia para la toma de decisiones.
# - Las variables utilizadas fueron:
#
# * Métrica de Movilidad (JamsDelay): Representa el retraso total acumulado (en minutos) derivado de la congestión en la red vial monitoreada.
# Relevancia: Esta variable constituye el indicador directo de la fricción operativa y la ineficiencia del sistema de movilidad urbana.
#
# *Métrica de Productividad Económica (City GDP/capita): Expresa el Producto Interno Bruto en dólares (USD) escalado por habitante.
# Relevancia: Funciona como un indicador del nivel de riqueza y desarrollo económico local. Al ser una métrica normalizada, permite comparar el potencial de consumo y la capacidad productiva entre ciudades de distintos tamaños. Sin embargo, para la planificación urbana, debe interpretarse con cautela, ya que no refleja el volumen total de actividad económica que físicamente presiona a la infraestructura vial.
#
# **Cobertura de datos:**
# - Especifica los años analizados, número de ciudades y países incluidos.
#   Se analizaron los datos que se extrajeron en el año 2024, considerando 15 ciudades distribuidas en 7 países. Los países analizados en el presente estudio pertencen a la región de Latinoamérica.
#
# **Metodología (alto nivel):**
# - Describe los procesos principales: limpieza de datos (formatos, estandarización de columnas).
#
# 1. Dataset de Tráfico (tomtom_traffic.csv)
# Estandarización y Casting: Se realizó el ajuste de los tipos de datos (casting) según el diccionario de variables, asegurando la integridad de columnas como Country, City y UpdateTimeUTC.
#
# Limpieza de Nulos: Se aplicó un protocolo de verificación para confirmar la inexistencia de valores nulos o faltantes, garantizando la robustez de los cálculos posteriores.
#
# Normalización de Formato: Se estandarizaron los encabezados de las columnas bajo un formato único y coherente.
#
# Ingeniería de Características (Feature Engineering): Se extrajo el año de la medición como una nueva variable independiente para facilitar el filtrado temporal.
#
# Segmentación y Agregación: Se filtró el conjunto de datos para el periodo 2024 y se aplicó una agrupación por ciudad, país y año. Los datos fueron consolidados mediante el promedio de las mediciones, permitiendo que el estudio se centre en el comportamiento medio anual de cada localidad.
#
# 2. Dataset Económico (oecd_city_economy.csv)
# Validación de Tipos y Calidad: Se ajustaron las variables económicas (como City GDP/capita y Unemployment) a sus formatos correspondientes y se validó la ausencia de registros nulos.
#
# Consistencia de Nombres: Se renombraron las columnas para asegurar la compatibilidad total con el primer dataset durante la fase de integración.
#
# Filtrado Temporal: Se seleccionaron exclusivamente los registros correspondientes al año 2024, alineando la ventana de observación económica con la de movilidad.
#
#
# - Explica la agregación por ciudad–año y el uso de una unión INNER para integrar tráfico y economía.
#
# La agregación de los datos se realizó mediante una agrupación por año, ciudad y país, consolidando las variables de interés para el análisis. Posteriormente, la integración de los conjuntos de datos se ejecutó a través de un INNER JOIN, tomando como llaves de cruce la ciudad y el año de registro. Este proceso de filtrado resultó en una muestra final de 15 localidades distribuidas en 7 países, garantizando la consistencia y disponibilidad de información en ambas dimensiones para el estudio.
#
#
# - Menciona las validaciones visuales empleadas (distribuciones, outliers, tendencias generales).
#
# Se utilizó un boxplot para analizar los valores retrado en el tráfico en minutos, con el cual se demostró que la mayor parte de los datos son consistentes y concentrados, en su mayoría alrededor de la media.
#
# Se elaboró un histograma con el propósito de analizar el comportamiento del Producto Interno Bruto (PIB) per cápita entre las diferentes ciudades incluidas en el conjunto de datos. A partir de este gráfico se observa una distribución con características cercanas a la normalidad, en la que la mayor concentración de valores se ubica alrededor de la media. Por el contrario, las ciudades que presentan los valores más bajos y más altos de PIB per cápita aparecen con una frecuencia menor dentro de la muestra. Este comportamiento sugiere que el conjunto de datos no presenta un sesgo significativo en la distribución del PIB per cápita entre las ciudades consideradas en el estudio.
#
# El tercer gráfico empleado corresponde a un diagrama de barras, el cual se utiliza para realizar el análisis central en el que se fundamenta el estudio y a partir del cual se obtienen los resultados presentados. A diferencia de los gráficos anteriores, este no constituye un mecanismo de validación de los datos, sino una herramienta analítica utilizada para la generación e interpretación de los resultados del estudio.
#
# **Hallazgos iniciales:**
# - Resume los patrones más importantes entre índices de tráfico y PIB per cápita.
#
# - - Destaca anomalías u outliers que podrían requerir revisión adicional o un análisis más profundo.
#
# En ciudades con alta densidad de población, como Ciudad de México, Lima y Bogotá, se observa una relación estrecha entre el PIB per cápita —como indicador del nivel de riqueza de una ciudad— y los problemas asociados a la viabilidad urbana. Este resultado resulta coherente, ya que a mayores niveles de ingreso aumenta la probabilidad de que una mayor proporción de la población disponga de vehículos particulares, lo que puede contribuir a la saturación de la infraestructura vial.
#
# Es importante destacar el caso de Montevideo. A diferencia de las ciudades anteriormente mencionadas, esta presenta una menor densidad de población y, al mismo tiempo, un PIB per cápita relativamente elevado. En este contexto, la menor concentración poblacional reduce la probabilidad de que se produzcan niveles comparables de saturación vial, a pesar del mayor poder adquisitivo de la población.
#
# Por lo tanto, se puede concluir que, si bien el PIB per cápita constituye un indicador útil para realizar este tipo de análisis en ciudades con niveles de densidad poblacional similares, por sí solo no permite obtener una visión completa del problema en contextos urbanos heterogéneos. En consecuencia, se recomienda incorporar otras métricas que permitan analizar el fenómeno en términos absolutos y capturar con mayor precisión la magnitud real de los problemas de viabilidad urbana.
#
# **Recomendaciones**
# Aterriza los hallazgos en acciones: ciudades prioritarias, necesidad de validar fuentes, requerimiento de análisis adicionales, o propuestas de inversión.
#
# - ¿Qué ciudad : Bogotá, Lima o Buenos Aires o alguna otra en particular, muestra la mayor correlación significativa entre altos niveles de congestión vehicular y bajos indicadores de productividad económica, sugiriendo ser una ciudad prioritaria para inversión en infraestructura de transporte?
#
# Las ciudades que deberían priorizarse en el presente estudio son Ciudad de México y São Paulo, ya que presentan los mayores problemas asociados a la viabilidad urbana. Estas condiciones pueden derivar, en el mediano y largo plazo, en limitaciones para el crecimiento económico de dichas ciudades si no se implementan medidas que mitiguen la saturación de la infraestructura vial.
#
# En este sentido, se recomienda que, a medida que aumenten los niveles de ingreso en estas ciudades, se realicen inversiones sostenidas en infraestructura y gestión de la movilidad urbana. De esta forma, se podría mejorar la eficiencia del sistema de transporte y permitir que el crecimiento económico vaya acompañado de mejoras en la movilidad y la accesibilidad urbana. De lo contrario, la congestión podría convertirse en un factor que limite el desarrollo económico.
#
# Asimismo, otras ciudades como Lima y Bogotá también muestran indicios de enfrentar problemáticas similares, aunque en menor magnitud. En estos casos, resulta conveniente monitorear la evolución de los indicadores de movilidad y desarrollo económico, con el objetivo de anticipar tendencias similares a las observadas en las ciudades previamente mencionadas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Excelente conclusiones. Tu descripcion detallada de los hallazgos y tus propuestas de accion en terminos de infraestructura, son muy buenas. Te felicito por tu desempeño.
